# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhilraghav018/Project_CaseStudies_Machine_and_Deep_Learning/blob/main/notebooks%20/Movie%20Recommender%20System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CODE TO IMPLEMENT A RECOMMEDER SYSTEM

# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# - This notebook implements a movie recommender system.
# - Recommender systems are used to suggest movies or songs to users based on their interest or usage history.
# - For example, Netflix recommends movies to watch based on the previous movies you've watched.
# - In this example, we will use Item-based Collaborative Filter
#
#
#
# - Dataset MovieLens: https://grouplens.org/datasets/movielens/100k/
# - Photo Credit: https://pxhere.com/en/photo/1588369

# %% [markdown]
# # STEP #0: LIBRARIES IMPORT

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # STEP #1: IMPORT DATASET

# %%
# Two datasets are available, let's load the first one:
movie_titles_df = pd.read_csv("/Users/nikhildharmaram/Documents/Project_Casestudies_Machine_and_Deep_Learning/data/Movie_Id_Titles")
movie_titles_df
# Out:
#       item_id                                      title
# 0           1                           Toy Story (1995)
# 1           2                           GoldenEye (1995)
# 2           3                          Four Rooms (1995)
# 3           4                          Get Shorty (1995)
# 4           5                             Copycat (1995)
# ...       ...                                        ...
# 1677     1678                          Mat' i syn (1997)
# 1678     1679                           B. Monkey (1998)
# 1679     1680                       Sliding Doors (1998)
# 1680     1681                        You So Crazy (1994)
# 1681     1682  Scream of Stone (Schrei aus Stein) (1991)
#
# [1682 rows x 2 columns]

# %%
# Let's load the second one!
movies_rating_df = pd.read_csv('/Users/nikhildharmaram/Documents/Project_Casestudies_Machine_and_Deep_Learning/data/u.data',
                               sep='\t', names=['user_id', 'item_id', 'rating', 'timestamp'])

# %%
movies_rating_df.head(10)
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742
# 5       22      377       1  878887116
# 6      244       51       2  880606923
# 7      166      346       1  886397596
# 8      298      474       4  884182806
# 9      115      265       2  881171488

# %%
movies_rating_df
# Out:
#         user_id  item_id  rating  timestamp
# 0             0       50       5  881250949
# 1             0      172       5  881250949
# 2             0      133       1  881250949
# 3           196      242       3  881250949
# 4           186      302       3  891717742
# ...         ...      ...     ...        ...
# 99998       880      476       3  880175444
# 99999       716      204       5  879795543
# 100000      276     1090       1  874795795
# 100001       13      225       2  882399156
# 100002       12      203       3  879959583
#
# [100003 rows x 4 columns]

# %%
# Let's drop the timestamp
movies_rating_df.drop(['timestamp'], axis = 1, inplace = True)

# %%
movies_rating_df
# Out:
#         user_id  item_id  rating
# 0             0       50       5
# 1             0      172       5
# 2             0      133       1
# 3           196      242       3
# 4           186      302       3
# ...         ...      ...     ...
# 99998       880      476       3
# 99999       716      204       5
# 100000      276     1090       1
# 100001       13      225       2
# 100002       12      203       3
#
# [100003 rows x 3 columns]

# %%
movies_rating_df.describe()
# Out:
#              user_id        item_id         rating
# count  100003.000000  100003.000000  100003.000000
# mean      462.470876     425.520914       3.529864
# std       266.622454     330.797791       1.125704
# min         0.000000       1.000000       1.000000
# 25%       254.000000     175.000000       3.000000
# 50%       447.000000     322.000000       4.000000
# 75%       682.000000     631.000000       4.000000
# max       943.000000    1682.000000       5.000000

# %%
movies_rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100003 entries, 0 to 100002
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   user_id  100003 non-null  int64
#  1   item_id  100003 non-null  int64
#  2   rating   100003 non-null  int64
# dtypes: int64(3)
# memory usage: 2.3 MB

# %%
# Let's merge both dataframes together so we can have ID with the movie name
movies_rating_df = pd.merge(movies_rating_df, movie_titles_df, on = 'item_id')

# %%
movies_rating_df
# Out:
#         user_id  item_id  rating                            title
# 0             0       50       5                 Star Wars (1977)
# 1             0      172       5  Empire Strikes Back, The (1980)
# 2             0      133       1        Gone with the Wind (1939)
# 3           196      242       3                     Kolya (1996)
# 4           186      302       3         L.A. Confidential (1997)
# ...         ...      ...     ...                              ...
# 99998       880      476       3     First Wives Club, The (1996)
# 99999       716      204       5        Back to the Future (1985)
# 100000      276     1090       1                    Sliver (1993)
# 100001       13      225       2            101 Dalmatians (1996)
# 100002       12      203       3                Unforgiven (1992)
#
# [100003 rows x 4 columns]

# %%
movies_rating_df.shape
# Out:
# (100003, 4)

# %% [markdown]
# # STEP #2: VISUALIZE DATASET

# %%
movies_rating_df.groupby('title')['rating'].describe()
# Out:
#                                        count      mean       std  min   25%  \
# title
# 'Til There Was You (1997)                9.0  2.333333  1.000000  1.0  2.00
# 1-900 (1994)                             5.0  2.600000  1.516575  1.0  1.00
# 101 Dalmatians (1996)                  109.0  2.908257  1.076184  1.0  2.00
# 12 Angry Men (1957)                    125.0  4.344000  0.719588  2.0  4.00
# 187 (1997)                              41.0  3.024390  1.172344  1.0  2.00
# ...                                      ...       ...       ...  ...   ...
# Young Guns II (1990)                    44.0  2.772727  1.008421  1.0  2.00
# Young Poisoner's Handbook, The (1995)   41.0  3.341463  1.237129  1.0  3.00
# Zeus and Roxanne (1997)                  6.0  2.166667  0.983192  1.0  1.25
# unknown                                  9.0  3.444444  1.130388  1.0  3.00
# Á köldum klaka (Cold Fever) (1994)       1.0  3.000000       NaN  3.0  3.00
#
#                                        50%  75%  max
# title
# 'Til There Was You (1997)              2.0  3.0  4.0
# 1-900 (1994)                           3.0  4.0  4.0
# 101 Dalmatians (1996)                  3.0  4.0  5.0
# 12 Angry Men (1957)                    4.0  5.0  5.0
# 187 (1997)                             3.0  4.0  5.0
# ...                                    ...  ...  ...
# Young Guns II (1990)                   3.0  3.0  5.0
# Young Poisoner's Handbook, The (1995)  4.0  4.0  5.0
# Zeus and Roxanne (1997)                2.5  3.0  3.0
# unknown                                4.0  4.0  5.0
# Á köldum klaka (Cold Fever) (1994)     3.0  3.0  3.0
#
# [1664 rows x 8 columns]

# %%
ratings_df_mean = movies_rating_df.groupby('title')['rating'].describe()['mean']
ratings_df_mean
# Out:
# title
# 'Til There Was You (1997)                2.333333
# 1-900 (1994)                             2.600000
# 101 Dalmatians (1996)                    2.908257
# 12 Angry Men (1957)                      4.344000
# 187 (1997)                               3.024390
#                                            ...
# Young Guns II (1990)                     2.772727
# Young Poisoner's Handbook, The (1995)    3.341463
# Zeus and Roxanne (1997)                  2.166667
# unknown                                  3.444444
# Á köldum klaka (Cold Fever) (1994)       3.000000
# Name: mean, Length: 1664, dtype: float64

# %%
ratings_df_count = movies_rating_df.groupby('title')['rating'].describe()['count']
ratings_df_count
# Out:
# title
# 'Til There Was You (1997)                  9.0
# 1-900 (1994)                               5.0
# 101 Dalmatians (1996)                    109.0
# 12 Angry Men (1957)                      125.0
# 187 (1997)                                41.0
#                                          ...
# Young Guns II (1990)                      44.0
# Young Poisoner's Handbook, The (1995)     41.0
# Zeus and Roxanne (1997)                    6.0
# unknown                                    9.0
# Á köldum klaka (Cold Fever) (1994)         1.0
# Name: count, Length: 1664, dtype: float64

# %%
ratings_mean_count_df = pd.concat([ratings_df_count, ratings_df_mean], axis = 1)

# %%
ratings_mean_count_df.reset_index()
# Out:
#                                       title  count      mean
# 0                 'Til There Was You (1997)    9.0  2.333333
# 1                              1-900 (1994)    5.0  2.600000
# 2                     101 Dalmatians (1996)  109.0  2.908257
# 3                       12 Angry Men (1957)  125.0  4.344000
# 4                                187 (1997)   41.0  3.024390
# ...                                     ...    ...       ...
# 1659                   Young Guns II (1990)   44.0  2.772727
# 1660  Young Poisoner's Handbook, The (1995)   41.0  3.341463
# 1661                Zeus and Roxanne (1997)    6.0  2.166667
# 1662                                unknown    9.0  3.444444
# 1663     Á köldum klaka (Cold Fever) (1994)    1.0  3.000000
#
# [1664 rows x 3 columns]

# %%
ratings_mean_count_df['mean'].plot(bins=100, kind='hist', color = 'r')
# Out:
# <Axes: ylabel='Frequency'>

# %%
ratings_mean_count_df['count'].plot(bins=100, kind='hist', color = 'b')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Let's see the highest rated movies!
# Apparently these movies does not have many reviews (i.e.: small number of ratings)

ratings_mean_count_df[ratings_mean_count_df['mean'] == 5]
# Out:
#                                                    count  mean
# title
# Aiqing wansui (1994)                                 1.0   5.0
# Entertaining Angels: The Dorothy Day Story (1996)    1.0   5.0
# Great Day in Harlem, A (1994)                        1.0   5.0
# Marlene Dietrich: Shadow and Light (1996)            1.0   5.0
# Prefontaine (1997)                                   3.0   5.0
# Saint of Fort Washington, The (1993)                 2.0   5.0
# Santa with Muscles (1996)                            2.0   5.0
# Someone Else's America (1995)                        1.0   5.0
# Star Kid (1997)                                      3.0   5.0
# They Made Me a Criminal (1939)                       1.0   5.0

# %%
# List all the movies that are most rated
# Please note that they are not necessarily have the highest rating (mean)

ratings_mean_count_df.sort_values('count', ascending = False).head(100)
# Out:
#                               count      mean
# title
# Star Wars (1977)              584.0  4.359589
# Contact (1997)                509.0  3.803536
# Fargo (1996)                  508.0  4.155512
# Return of the Jedi (1983)     507.0  4.007890
# Liar Liar (1997)              485.0  3.156701
# ...                             ...       ...
# Aladdin (1992)                219.0  3.812785
# Babe (1995)                   219.0  3.995434
# Volcano (1997)                219.0  2.808219
# To Kill a Mockingbird (1962)  219.0  4.292237
# Murder at 1600 (1997)         218.0  3.087156
#
# [100 rows x 2 columns]

# %%
ratings_mean_count_df.sort_values('count', ascending = True).head(100)
# Out:
#                                                     count  mean
# title
# Á köldum klaka (Cold Fever) (1994)                    1.0   3.0
# Mille bolle blu (1993)                                1.0   1.0
# Mat' i syn (1997)                                     1.0   1.0
# Marlene Dietrich: Shadow and Light (1996)             1.0   5.0
# Man from Down Under, The (1943)                       1.0   1.0
# ...                                                   ...   ...
# The Courtyard (1995)                                  1.0   1.0
# Vie est belle, La (Life is Rosey) (1987)              1.0   1.0
# Silence of the Palace, The (Saimt el Qusur) (1994)    1.0   3.0
# Very Natural Thing, A (1974)                          1.0   1.0
# Vermont Is For Lovers (1992)                          1.0   1.0
#
# [100 rows x 2 columns]

# %% [markdown]
# # STEP #3: PERFORM ITEM-BASED COLLABORATIVE FILTERING ON ONE MOVIE SAMPLE

# %%
userid_movietitle_matrix = movies_rating_df.pivot_table(index = 'user_id', columns = 'title', values = 'rating')
userid_movietitle_matrix
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# ...                            ...           ...                    ...
# 939                            NaN           NaN                    NaN
# 940                            NaN           NaN                    NaN
# 941                            NaN           NaN                    NaN
# 942                            NaN           NaN                    NaN
# 943                            NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
# ...                      ...         ...                          ...
# 939                      NaN         NaN                          NaN
# 940                      NaN         NaN                          NaN
# 941                      NaN         NaN                          NaN
# 942                      NaN         NaN                          NaN
# 943                      NaN         NaN                          2.0
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# 0                                        NaN                           NaN
# 1                                        3.0                           4.0
# 2                                        NaN                           NaN
# 3                                        NaN                           NaN
# 4                                        NaN                           NaN
# ...                                      ...                           ...
# 939                                      NaN                           NaN
# 940                                      NaN                           NaN
# 941                                      NaN                           NaN
# 942                                      NaN                           3.0
# 943                                      NaN                           NaN
#
# title    3 Ninjas: High Noon At Mega Mountain (1998)  39 Steps, The (1935)  \
# user_id
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                1.0                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
# ...                                              ...                   ...
# 939                                              NaN                   NaN
# 940                                              NaN                   NaN
# 941                                              NaN                   NaN
# 942                                              NaN                   3.0
# 943                                              NaN                   NaN
#
# title    ...  Yankee Zulu (1994)  Year of the Horse (1997)  \
# user_id  ...
# 0        ...                 NaN                       NaN
# 1        ...                 NaN                       NaN
# 2        ...                 NaN                       NaN
# 3        ...                 NaN                       NaN
# 4        ...                 NaN                       NaN
# ...      ...                 ...                       ...
# 939      ...                 NaN                       NaN
# 940      ...                 NaN                       NaN
# 941      ...                 NaN                       NaN
# 942      ...                 NaN                       NaN
# 943      ...                 NaN                       NaN
#
# title    You So Crazy (1994)  Young Frankenstein (1974)  Young Guns (1988)  \
# user_id
# 0                        NaN                        NaN                NaN
# 1                        NaN                        5.0                3.0
# 2                        NaN                        NaN                NaN
# 3                        NaN                        NaN                NaN
# 4                        NaN                        NaN                NaN
# ...                      ...                        ...                ...
# 939                      NaN                        NaN                NaN
# 940                      NaN                        NaN                NaN
# 941                      NaN                        NaN                NaN
# 942                      NaN                        NaN                NaN
# 943                      NaN                        NaN                4.0
#
# title    Young Guns II (1990)  Young Poisoner's Handbook, The (1995)  \
# user_id
# 0                         NaN                                    NaN
# 1                         NaN                                    NaN
# 2                         NaN                                    NaN
# 3                         NaN                                    NaN
# 4                         NaN                                    NaN
# ...                       ...                                    ...
# 939                       NaN                                    NaN
# 940                       NaN                                    NaN
# 941                       NaN                                    NaN
# 942                       NaN                                    NaN
# 943                       3.0                                    NaN
#
# title    Zeus and Roxanne (1997)  unknown  Á köldum klaka (Cold Fever) (1994)
# user_id
# 0                            NaN      NaN                                 NaN
# 1                            NaN      4.0                                 NaN
# 2                            NaN      NaN                                 NaN
# 3                            NaN      NaN                                 NaN
# 4                            NaN      NaN                                 NaN
# ...                          ...      ...                                 ...
# 939                          NaN      NaN                                 NaN
# 940                          NaN      NaN                                 NaN
# 941                          NaN      NaN                                 NaN
# 942                          NaN      NaN                                 NaN
# 943                          NaN      NaN                                 NaN
#
# [944 rows x 1664 columns]

# %%
titanic = userid_movietitle_matrix['Titanic (1997)']
titanic
# Out:
# user_id
# 0      NaN
# 1      NaN
# 2      5.0
# 3      NaN
# 4      NaN
#       ...
# 939    NaN
# 940    5.0
# 941    NaN
# 942    3.0
# 943    NaN
# Name: Titanic (1997), Length: 944, dtype: float64

# %%
# Let's calculate the correlations
titanic_correlations = pd.DataFrame(userid_movietitle_matrix.corrwith(titanic), columns=['Correlation'])
titanic_correlations = titanic_correlations.join(ratings_mean_count_df['count'])
# Out:
# /Users/nikhildharmaram/Documents/Project_Casestudies_Machine_and_Deep_Learning/venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3015: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /Users/nikhildharmaram/Documents/Project_Casestudies_Machine_and_Deep_Learning/venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2888: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /Users/nikhildharmaram/Documents/Project_Casestudies_Machine_and_Deep_Learning/venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2888: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# /Users/nikhildharmaram/Documents/Project_Casestudies_Machine_and_Deep_Learning/venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/nikhildharmaram/Documents/Project_Casestudies_Machine_and_Deep_Learning/venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
titanic_correlations
# Out:
#                                        Correlation  count
# title
# 'Til There Was You (1997)                -0.062017    9.0
# 1-900 (1994)                                   NaN    5.0
# 101 Dalmatians (1996)                     0.120113  109.0
# 12 Angry Men (1957)                       0.077700  125.0
# 187 (1997)                                0.315654   41.0
# ...                                            ...    ...
# Young Guns II (1990)                      0.317274   44.0
# Young Poisoner's Handbook, The (1995)     0.356783   41.0
# Zeus and Roxanne (1997)                        NaN    6.0
# unknown                                        NaN    9.0
# Á köldum klaka (Cold Fever) (1994)             NaN    1.0
#
# [1664 rows x 2 columns]

# %%
titanic_correlations.dropna(inplace=True)
titanic_correlations
# Out:
#                                        Correlation  count
# title
# 'Til There Was You (1997)                -0.062017    9.0
# 101 Dalmatians (1996)                     0.120113  109.0
# 12 Angry Men (1957)                       0.077700  125.0
# 187 (1997)                                0.315654   41.0
# 2 Days in the Valley (1996)               0.017295   93.0
# ...                                            ...    ...
# Year of the Horse (1997)                  1.000000    7.0
# Young Frankenstein (1974)                 0.107666  200.0
# Young Guns (1988)                         0.199931  101.0
# Young Guns II (1990)                      0.317274   44.0
# Young Poisoner's Handbook, The (1995)     0.356783   41.0
#
# [1356 rows x 2 columns]

# %%
# Let's sort the correlations vector
titanic_correlations.sort_values('Correlation', ascending=False)
# Out:
#                                           Correlation  count
# title
# Newton Boys, The (1998)                           1.0    4.0
# Pest, The (1997)                                  1.0    8.0
# Amazing Panda Adventure, The (1995)               1.0   10.0
# Savage Nights (Nuits fauves, Les) (1992)          1.0    3.0
# Hideaway (1995)                                   1.0    9.0
# ...                                               ...    ...
# Blood Beach (1981)                               -1.0    6.0
# Alphaville (1965)                                -1.0   12.0
# Caro Diario (Dear Diary) (1994)                  -1.0    4.0
# Two Bits (1995)                                  -1.0    5.0
# The Innocent (1994)                              -1.0    4.0
#
# [1356 rows x 2 columns]

# %%
titanic_correlations[titanic_correlations['count']>80].sort_values('Correlation',ascending=False).head()
# Out:
#                               Correlation  count
# title
# Titanic (1997)                   1.000000  350.0
# River Wild, The (1994)           0.497600  146.0
# Abyss, The (1989)                0.472103  151.0
# Bram Stoker's Dracula (1992)     0.443560  120.0
# True Lies (1994)                 0.435104  208.0

# %%
star_wars = userid_movietitle_matrix['Star Wars (1977)']
star_wars
# Out:
# user_id
# 0      5.0
# 1      5.0
# 2      5.0
# 3      NaN
# 4      5.0
#       ...
# 939    NaN
# 940    4.0
# 941    NaN
# 942    5.0
# 943    4.0
# Name: Star Wars (1977), Length: 944, dtype: float64

# %%
star_wars_correlations = pd.DataFrame(userid_movietitle_matrix.corrwith(star_wars), columns=['Correlation'])
star_wars_correlations = star_wars_correlations.join(ratings_mean_count_df['count'])
# Out:
# /Users/nikhildharmaram/Documents/Project_Casestudies_Machine_and_Deep_Learning/venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/nikhildharmaram/Documents/Project_Casestudies_Machine_and_Deep_Learning/venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Users/nikhildharmaram/Documents/Project_Casestudies_Machine_and_Deep_Learning/venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3015: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /Users/nikhildharmaram/Documents/Project_Casestudies_Machine_and_Deep_Learning/venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2888: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /Users/nikhildharmaram/Documents/Project_Casestudies_Machine_and_Deep_Learning/venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2888: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)

# %%
star_wars_correlations
# Out:
#                                        Correlation  count
# title
# 'Til There Was You (1997)                 0.872872    9.0
# 1-900 (1994)                             -0.645497    5.0
# 101 Dalmatians (1996)                     0.211132  109.0
# 12 Angry Men (1957)                       0.184289  125.0
# 187 (1997)                                0.027398   41.0
# ...                                            ...    ...
# Young Guns II (1990)                      0.228615   44.0
# Young Poisoner's Handbook, The (1995)    -0.007374   41.0
# Zeus and Roxanne (1997)                   0.818182    6.0
# unknown                                   0.723123    9.0
# Á köldum klaka (Cold Fever) (1994)             NaN    1.0
#
# [1664 rows x 2 columns]

# %%
star_wars_correlations.dropna(inplace=True)
star_wars_correlations
# Out:
#                                        Correlation  count
# title
# 'Til There Was You (1997)                 0.872872    9.0
# 1-900 (1994)                             -0.645497    5.0
# 101 Dalmatians (1996)                     0.211132  109.0
# 12 Angry Men (1957)                       0.184289  125.0
# 187 (1997)                                0.027398   41.0
# ...                                            ...    ...
# Young Guns (1988)                         0.186377  101.0
# Young Guns II (1990)                      0.228615   44.0
# Young Poisoner's Handbook, The (1995)    -0.007374   41.0
# Zeus and Roxanne (1997)                   0.818182    6.0
# unknown                                   0.723123    9.0
#
# [1410 rows x 2 columns]

# %%
star_wars_correlations.sort_values('Correlation', ascending=False)
# Out:
#                                    Correlation  count
# title
# Hollow Reed (1996)                         1.0    6.0
# Stripes (1981)                             1.0    5.0
# Star Wars (1977)                           1.0  584.0
# Beans of Egypt, Maine, The (1994)          1.0    2.0
# Safe Passage (1994)                        1.0    2.0
# ...                                        ...    ...
# For Ever Mozart (1996)                    -1.0    3.0
# Frankie Starlight (1995)                  -1.0    4.0
# I Like It Like That (1994)                -1.0    3.0
# American Dream (1990)                     -1.0    2.0
# Theodore Rex (1995)                       -1.0    5.0
#
# [1410 rows x 2 columns]

# %%
star_wars_correlations[star_wars_correlations['count']>80].sort_values('Correlation',ascending=False).head()
# Out:
#                                                     Correlation  count
# title
# Star Wars (1977)                                       1.000000  584.0
# Empire Strikes Back, The (1980)                        0.748353  368.0
# Return of the Jedi (1983)                              0.672556  507.0
# Raiders of the Lost Ark (1981)                         0.536117  420.0
# Austin Powers: International Man of Mystery (1997)     0.377433  130.0

# %% [markdown]
# # STEP#4: CREATE AN ITEM-BASED COLLABORATIVE FILTER ON THE ENTIRE DATASET

# %%
# Recall this matrix that we created earlier of all movies and their user ID/ratings
userid_movietitle_matrix
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# ...                            ...           ...                    ...
# 939                            NaN           NaN                    NaN
# 940                            NaN           NaN                    NaN
# 941                            NaN           NaN                    NaN
# 942                            NaN           NaN                    NaN
# 943                            NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
# ...                      ...         ...                          ...
# 939                      NaN         NaN                          NaN
# 940                      NaN         NaN                          NaN
# 941                      NaN         NaN                          NaN
# 942                      NaN         NaN                          NaN
# 943                      NaN         NaN                          2.0
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# 0                                        NaN                           NaN
# 1                                        3.0                           4.0
# 2                                        NaN                           NaN
# 3                                        NaN                           NaN
# 4                                        NaN                           NaN
# ...                                      ...                           ...
# 939                                      NaN                           NaN
# 940                                      NaN                           NaN
# 941                                      NaN                           NaN
# 942                                      NaN                           3.0
# 943                                      NaN                           NaN
#
# title    3 Ninjas: High Noon At Mega Mountain (1998)  39 Steps, The (1935)  \
# user_id
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                1.0                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
# ...                                              ...                   ...
# 939                                              NaN                   NaN
# 940                                              NaN                   NaN
# 941                                              NaN                   NaN
# 942                                              NaN                   3.0
# 943                                              NaN                   NaN
#
# title    ...  Yankee Zulu (1994)  Year of the Horse (1997)  \
# user_id  ...
# 0        ...                 NaN                       NaN
# 1        ...                 NaN                       NaN
# 2        ...                 NaN                       NaN
# 3        ...                 NaN                       NaN
# 4        ...                 NaN                       NaN
# ...      ...                 ...                       ...
# 939      ...                 NaN                       NaN
# 940      ...                 NaN                       NaN
# 941      ...                 NaN                       NaN
# 942      ...                 NaN                       NaN
# 943      ...                 NaN                       NaN
#
# title    You So Crazy (1994)  Young Frankenstein (1974)  Young Guns (1988)  \
# user_id
# 0                        NaN                        NaN                NaN
# 1                        NaN                        5.0                3.0
# 2                        NaN                        NaN                NaN
# 3                        NaN                        NaN                NaN
# 4                        NaN                        NaN                NaN
# ...                      ...                        ...                ...
# 939                      NaN                        NaN                NaN
# 940                      NaN                        NaN                NaN
# 941                      NaN                        NaN                NaN
# 942                      NaN                        NaN                NaN
# 943                      NaN                        NaN                4.0
#
# title    Young Guns II (1990)  Young Poisoner's Handbook, The (1995)  \
# user_id
# 0                         NaN                                    NaN
# 1                         NaN                                    NaN
# 2                         NaN                                    NaN
# 3                         NaN                                    NaN
# 4                         NaN                                    NaN
# ...                       ...                                    ...
# 939                       NaN                                    NaN
# 940                       NaN                                    NaN
# 941                       NaN                                    NaN
# 942                       NaN                                    NaN
# 943                       3.0                                    NaN
#
# title    Zeus and Roxanne (1997)  unknown  Á köldum klaka (Cold Fever) (1994)
# user_id
# 0                            NaN      NaN                                 NaN
# 1                            NaN      4.0                                 NaN
# 2                            NaN      NaN                                 NaN
# 3                            NaN      NaN                                 NaN
# 4                            NaN      NaN                                 NaN
# ...                          ...      ...                                 ...
# 939                          NaN      NaN                                 NaN
# 940                          NaN      NaN                                 NaN
# 941                          NaN      NaN                                 NaN
# 942                          NaN      NaN                                 NaN
# 943                          NaN      NaN                                 NaN
#
# [944 rows x 1664 columns]

# %%
movie_correlations = userid_movietitle_matrix.corr(method = 'pearson', min_periods = 80)
movie_correlations

# pearson : standard correlation coefficient
# Obtain the correlations between all movies in the dataframe
# Out:
# title                                  'Til There Was You (1997)  \
# title
# 'Til There Was You (1997)                                    NaN
# 1-900 (1994)                                                 NaN
# 101 Dalmatians (1996)                                        NaN
# 12 Angry Men (1957)                                          NaN
# 187 (1997)                                                   NaN
# ...                                                          ...
# Young Guns II (1990)                                         NaN
# Young Poisoner's Handbook, The (1995)                        NaN
# Zeus and Roxanne (1997)                                      NaN
# unknown                                                      NaN
# Á köldum klaka (Cold Fever) (1994)                           NaN
#
# title                                  1-900 (1994)  101 Dalmatians (1996)  \
# title
# 'Til There Was You (1997)                       NaN                    NaN
# 1-900 (1994)                                    NaN                    NaN
# 101 Dalmatians (1996)                           NaN                    1.0
# 12 Angry Men (1957)                             NaN                    NaN
# 187 (1997)                                      NaN                    NaN
# ...                                             ...                    ...
# Young Guns II (1990)                            NaN                    NaN
# Young Poisoner's Handbook, The (1995)           NaN                    NaN
# Zeus and Roxanne (1997)                         NaN                    NaN
# unknown                                         NaN                    NaN
# Á köldum klaka (Cold Fever) (1994)              NaN                    NaN
#
# title                                  12 Angry Men (1957)  187 (1997)  \
# title
# 'Til There Was You (1997)                              NaN         NaN
# 1-900 (1994)                                           NaN         NaN
# 101 Dalmatians (1996)                                  NaN         NaN
# 12 Angry Men (1957)                                    1.0         NaN
# 187 (1997)                                             NaN         NaN
# ...                                                    ...         ...
# Young Guns II (1990)                                   NaN         NaN
# Young Poisoner's Handbook, The (1995)                  NaN         NaN
# Zeus and Roxanne (1997)                                NaN         NaN
# unknown                                                NaN         NaN
# Á köldum klaka (Cold Fever) (1994)                     NaN         NaN
#
# title                                  2 Days in the Valley (1996)  \
# title
# 'Til There Was You (1997)                                      NaN
# 1-900 (1994)                                                   NaN
# 101 Dalmatians (1996)                                          NaN
# 12 Angry Men (1957)                                            NaN
# 187 (1997)                                                     NaN
# ...                                                            ...
# Young Guns II (1990)                                           NaN
# Young Poisoner's Handbook, The (1995)                          NaN
# Zeus and Roxanne (1997)                                        NaN
# unknown                                                        NaN
# Á köldum klaka (Cold Fever) (1994)                             NaN
#
# title                                  20,000 Leagues Under the Sea (1954)  \
# title
# 'Til There Was You (1997)                                              NaN
# 1-900 (1994)                                                           NaN
# 101 Dalmatians (1996)                                                  NaN
# 12 Angry Men (1957)                                                    NaN
# 187 (1997)                                                             NaN
# ...                                                                    ...
# Young Guns II (1990)                                                   NaN
# Young Poisoner's Handbook, The (1995)                                  NaN
# Zeus and Roxanne (1997)                                                NaN
# unknown                                                                NaN
# Á köldum klaka (Cold Fever) (1994)                                     NaN
#
# title                                  2001: A Space Odyssey (1968)  \
# title
# 'Til There Was You (1997)                                       NaN
# 1-900 (1994)                                                    NaN
# 101 Dalmatians (1996)                                           NaN
# 12 Angry Men (1957)                                        0.178848
# 187 (1997)                                                      NaN
# ...                                                             ...
# Young Guns II (1990)                                            NaN
# Young Poisoner's Handbook, The (1995)                           NaN
# Zeus and Roxanne (1997)                                         NaN
# unknown                                                         NaN
# Á köldum klaka (Cold Fever) (1994)                              NaN
#
# title                                  3 Ninjas: High Noon At Mega Mountain (1998)  \
# title
# 'Til There Was You (1997)                                                      NaN
# 1-900 (1994)                                                                   NaN
# 101 Dalmatians (1996)                                                          NaN
# 12 Angry Men (1957)                                                            NaN
# 187 (1997)                                                                     NaN
# ...                                                                            ...
# Young Guns II (1990)                                                           NaN
# Young Poisoner's Handbook, The (1995)                                          NaN
# Zeus and Roxanne (1997)                                                        NaN
# unknown                                                                        NaN
# Á köldum klaka (Cold Fever) (1994)                                             NaN
#
# title                                  39 Steps, The (1935)  ...  \
# title                                                        ...
# 'Til There Was You (1997)                               NaN  ...
# 1-900 (1994)                                            NaN  ...
# 101 Dalmatians (1996)                                   NaN  ...
# 12 Angry Men (1957)                                     NaN  ...
# 187 (1997)                                              NaN  ...
# ...                                                     ...  ...
# Young Guns II (1990)                                    NaN  ...
# Young Poisoner's Handbook, The (1995)                   NaN  ...
# Zeus and Roxanne (1997)                                 NaN  ...
# unknown                                                 NaN  ...
# Á köldum klaka (Cold Fever) (1994)                      NaN  ...
#
# title                                  Yankee Zulu (1994)  \
# title
# 'Til There Was You (1997)                             NaN
# 1-900 (1994)                                          NaN
# 101 Dalmatians (1996)                                 NaN
# 12 Angry Men (1957)                                   NaN
# 187 (1997)                                            NaN
# ...                                                   ...
# Young Guns II (1990)                                  NaN
# Young Poisoner's Handbook, The (1995)                 NaN
# Zeus and Roxanne (1997)                               NaN
# unknown                                               NaN
# Á köldum klaka (Cold Fever) (1994)                    NaN
#
# title                                  Year of the Horse (1997)  \
# title
# 'Til There Was You (1997)                                   NaN
# 1-900 (1994)                                                NaN
# 101 Dalmatians (1996)                                       NaN
# 12 Angry Men (1957)                                         NaN
# 187 (1997)                                                  NaN
# ...                                                         ...
# Young Guns II (1990)                                        NaN
# Young Poisoner's Handbook, The (1995)                       NaN
# Zeus and Roxanne (1997)                                     NaN
# unknown                                                     NaN
# Á köldum klaka (Cold Fever) (1994)                          NaN
#
# title                                  You So Crazy (1994)  \
# title
# 'Til There Was You (1997)                              NaN
# 1-900 (1994)                                           NaN
# 101 Dalmatians (1996)                                  NaN
# 12 Angry Men (1957)                                    NaN
# 187 (1997)                                             NaN
# ...                                                    ...
# Young Guns II (1990)                                   NaN
# Young Poisoner's Handbook, The (1995)                  NaN
# Zeus and Roxanne (1997)                                NaN
# unknown                                                NaN
# Á köldum klaka (Cold Fever) (1994)                     NaN
#
# title                                  Young Frankenstein (1974)  \
# title
# 'Til There Was You (1997)                                    NaN
# 1-900 (1994)                                                 NaN
# 101 Dalmatians (1996)                                        NaN
# 12 Angry Men (1957)                                          NaN
# 187 (1997)                                                   NaN
# ...                                                          ...
# Young Guns II (1990)                                         NaN
# Young Poisoner's Handbook, The (1995)                        NaN
# Zeus and Roxanne (1997)                                      NaN
# unknown                                                      NaN
# Á köldum klaka (Cold Fever) (1994)                           NaN
#
# title                                  Young Guns (1988)  \
# title
# 'Til There Was You (1997)                            NaN
# 1-900 (1994)                                         NaN
# 101 Dalmatians (1996)                                NaN
# 12 Angry Men (1957)                                  NaN
# 187 (1997)                                           NaN
# ...                                                  ...
# Young Guns II (1990)                                 NaN
# Young Poisoner's Handbook, The (1995)                NaN
# Zeus and Roxanne (1997)                              NaN
# unknown                                              NaN
# Á köldum klaka (Cold Fever) (1994)                   NaN
#
# title                                  Young Guns II (1990)  \
# title
# 'Til There Was You (1997)                               NaN
# 1-900 (1994)                                            NaN
# 101 Dalmatians (1996)                                   NaN
# 12 Angry Men (1957)                                     NaN
# 187 (1997)                                              NaN
# ...                                                     ...
# Young Guns II (1990)                                    NaN
# Young Poisoner's Handbook, The (1995)                   NaN
# Zeus and Roxanne (1997)                                 NaN
# unknown                                                 NaN
# Á köldum klaka (Cold Fever) (1994)                      NaN
#
# title                                  Young Poisoner's Handbook, The (1995)  \
# title
# 'Til There Was You (1997)                                                NaN
# 1-900 (1994)                                                             NaN
# 101 Dalmatians (1996)                                                    NaN
# 12 Angry Men (1957)                                                      NaN
# 187 (1997)                                                               NaN
# ...                                                                      ...
# Young Guns II (1990)                                                     NaN
# Young Poisoner's Handbook, The (1995)                                    NaN
# Zeus and Roxanne (1997)                                                  NaN
# unknown                                                                  NaN
# Á köldum klaka (Cold Fever) (1994)                                       NaN
#
# title                                  Zeus and Roxanne (1997)  unknown  \
# title
# 'Til There Was You (1997)                                  NaN      NaN
# 1-900 (1994)                                               NaN      NaN
# 101 Dalmatians (1996)                                      NaN      NaN
# 12 Angry Men (1957)                                        NaN      NaN
# 187 (1997)                                                 NaN      NaN
# ...                                                        ...      ...
# Young Guns II (1990)                                       NaN      NaN
# Young Poisoner's Handbook, The (1995)                      NaN      NaN
# Zeus and Roxanne (1997)                                    NaN      NaN
# unknown                                                    NaN      NaN
# Á köldum klaka (Cold Fever) (1994)                         NaN      NaN
#
# title                                  Á köldum klaka (Cold Fever) (1994)
# title
# 'Til There Was You (1997)                                             NaN
# 1-900 (1994)                                                          NaN
# 101 Dalmatians (1996)                                                 NaN
# 12 Angry Men (1957)                                                   NaN
# 187 (1997)                                                            NaN
# ...                                                                   ...
# Young Guns II (1990)                                                  NaN
# Young Poisoner's Handbook, The (1995)                                 NaN
# Zeus and Roxanne (1997)                                               NaN
# unknown                                                               NaN
# Á köldum klaka (Cold Fever) (1994)                                    NaN
#
# [1664 rows x 1664 columns]

# %%
# Let's create our own dataframe with our own ratings!
myRatings = pd.read_csv("/Users/nikhildharmaram/Documents/Project_Casestudies_Machine_and_Deep_Learning/data/My_Ratings.csv")
myRatings

#myRatings.reset_index
# Out:
#          Movie Name  Ratings
# 0  Liar Liar (1997)        5
# 1  Star Wars (1977)        1

# %%
len(myRatings.index)
# Out:
# 2

# %%
similar_movies_list = []

for i in range(0, len(myRatings.index)):
    similar_movie = movie_correlations[myRatings['Movie Name'][i]].dropna() # Get same movies with same ratings
    similar_movie = similar_movie.map(lambda x: x * myRatings['Ratings'][i]) # Scale the similarity by your given ratings
    similar_movies_list.append(similar_movie)
similar_movies_list = pd.concat(similar_movies_list)

# %%
# 1. Group duplicates (so the same movie from different suggestions adds up)
similar_movies_list = similar_movies_list.groupby(similar_movies_list.index).sum()

# 2. Sort (without the 'inplace' assignment trap)
similar_movies_list = similar_movies_list.sort_values(ascending=False)

# 3. Print
print(similar_movies_list.head(10))
# Out:
# title
# Liar Liar (1997)                             5.150292
# Con Air (1997)                               2.590845
# Pretty Woman (1990)                          2.470894
# Indiana Jones and the Last Crusade (1989)    2.422243
# Michael (1996)                               2.350934
# Top Gun (1986)                               2.203418
# Back to the Future (1985)                    2.164978
# Ghost and the Darkness, The (1996)           2.116499
# Field of Dreams (1989)                       2.086980
# Raiders of the Lost Ark (1981)               2.035313
# dtype: float64

# %% [markdown]
# # NOW WE HAVE PRODUCED THE TOP 20 MOVIE RECCOMENDATIONS FOR A PERSON WHO LIKES CERTAIN TYPE OR GENRE OF FILMS THROUGH MOVIE RECCOMENDER SYSTEMS!
